# %%
import pandas as pd
import numpy as np
import os 
import csv

# %% [markdown]
# Didn't use the CVS instead used Excel for all data
#
# tokyo_2020_df = pd.read_csv("2020 Tokyo Medals.csv")
# tokyo_2020_df = tokyo_2020_df.sort_values(by=['Country'])
# tokyo_2020_df = tokyo_2020_df.replace('United States of America', 'United States')
# tokyo_2020_df = tokyo_2020_df.replace("People's Republic of China",'China')
# tokyo_2020_df = tokyo_2020_df.replace('ROC','Russia')
# tokyo_2020_df = tokyo_2020_df.replace('Republic of Korea','North Korea')
# tokyo_2020_df = tokyo_2020_df.replace('Islamic Republic of Iran','Iran')
# tokyo_2020_df = tokyo_2020_df.replace('ROC','Russia')
#
# tokyo_2020_df

# %%
xlsx = pd.ExcelFile('RawData/2020 Data for Medals.xlsx')
athletes_2020_df = pd.read_excel(xlsx, 'Athletes')
Pop_GDP_2020_df = pd.read_excel(xlsx, 'Total Data')
Pop_GDP_2020_df
# Out:
#           YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0       2020Argentina      Argentina  2020     0       1       2      3
# 1         2020Armenia        Armenia  2020     0       2       2      4
# 2       2020Australia      Australia  2020    17       7      22     46
# 3         2020Austria        Austria  2020     1       1       5      7
# 4      2020Azerbaijan     Azerbaijan  2020     0       3       4      7
# ..                ...            ...   ...   ...     ...     ...    ...
# 88         2020Uganda         Uganda  2020     2       1       1      4
# 89        2020Ukraine        Ukraine  2020     1       6      12     19
# 90  2020United States  United States  2020    39      41      33    113
# 91     2020Uzbekistan     Uzbekistan  2020     3       0       2      5
# 92      2020Venezuela      Venezuela  2020     1       3       0      4
#
#     Population       GDP
# 0     45195774    637.43
# 1      2963243     11.54
# 2     25499884   1323.42
# 3      9006398    416.84
# 4     10139177     40.75
# ..         ...       ...
# 88    45741007     26.00
# 89    43733762    112.15
# 90   331002651  19485.39
# 91    33469203     49.68
# 92    31108083    316.48
#
# [93 rows x 9 columns]

# %%
athletes_2020_df
# Out:
#             Country  Athletes
# 0       Afghanistan         5
# 1           Albania         9
# 2           Algeria        44
# 3    American Samoa         6
# 4           Andorra         2
# ..              ...       ...
# 201         Vietnam        18
# 202  Virgin Islands         4
# 203           Yemen         5
# 204          Zambia        24
# 205        Zimbabwe         5
#
# [206 rows x 2 columns]

# %%
tokyo_2020_df = Pop_GDP_2020_df.merge(athletes_2020_df, left_on='Country', right_on='Country')
tokyo_2020_df = tokyo_2020_df[["YearCountry","Country", "Year","Gold","Silver","Bronze","Total","Athletes","Population","GDP"]]
tokyo_2020_df
# Out:
#           YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0       2020Argentina      Argentina  2020     0       1       2      3
# 1         2020Armenia        Armenia  2020     0       2       2      4
# 2       2020Australia      Australia  2020    17       7      22     46
# 3         2020Austria        Austria  2020     1       1       5      7
# 4      2020Azerbaijan     Azerbaijan  2020     0       3       4      7
# ..                ...            ...   ...   ...     ...     ...    ...
# 87         2020Uganda         Uganda  2020     2       1       1      4
# 88        2020Ukraine        Ukraine  2020     1       6      12     19
# 89  2020United States  United States  2020    39      41      33    113
# 90     2020Uzbekistan     Uzbekistan  2020     3       0       2      5
# 91      2020Venezuela      Venezuela  2020     1       3       0      4
#
#     Athletes  Population       GDP
# 0        174    45195774    637.43
# 1         17     2963243     11.54
# 2        478    25499884   1323.42
# 3         60     9006398    416.84
# 4         44    10139177     40.75
# ..       ...         ...       ...
# 87        21    45741007     26.00
# 88       155    43733762    112.15
# 89       613   331002651  19485.39
# 90        63    33469203     49.68
# 91        44    31108083    316.48
#
# [92 rows x 10 columns]

# %%
rio_2016_df = pd.read_csv("RawData/2016medalcount.csv")
rio_2016_df.head()
# Out:
#          YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0  2016United States  United States  2016    46      37      38    121
# 1  2016Great Britain  Great Britain  2016    27      23      17     67
# 2          2016China          China  2016    26      18      26     70
# 3         2016Russia         Russia  2016    19      17      20     56
# 4        2016Germany        Germany  2016    17      10      15     42
#
#    Athletes  Population       GDP
# 0       554   321418820  18036.65
# 1       366    65138232   2858.00
# 2       413  1371220000  11007.72
# 3       282   144096812   1310.21
# 4       425    81413145   3363.45

# %%
xlsx = pd.ExcelFile('RawData/2000_Olympics.xlsx')
sydney_2000_df = pd.read_excel(xlsx)
sydney_2000_df.head()
# Out:
#        YearCountry      Country  Year  Gold  Silver  Bronze  Total  Athletes  \
# 0    2000 Algeria      Algeria   2000     1       1       3      5        21
# 1  2000 Argentina    Argentina   2000     0       2       2      4        11
# 2    2000 Armenia      Armenia   2000     0       0       1      1         3
# 3  2000 Australia    Australia   2000    16      25      17     58        82
# 4    2000 Austria      Austria   2000     2       1       0      3        12
#
#       GDP  Population
# 0   54.79    30950322
# 1  284.20    36858473
# 2    1.91     3169445
# 3  416.89    19158366
# 4  192.07     8011561

# %%
xlsx = pd.ExcelFile('RawData/2004_Olympics.xlsx')
athens_2004_df = pd.read_excel(xlsx)
athens_2004_df.head()
# Out:
#         YearCountry       Country  Year  Gold  Silver  Bronze  Total  \
# 0   2004 Argentina     Argentina   2004     2       0       4      6
# 1   2004 Australia     Australia   2004    17      16      17     50
# 2     2004 Austria       Austria   2004     2       4       1      7
# 3  2004 Azerbaijan    Azerbaijan   2004     1       0       4      5
# 4     2004 Bahamas       Bahamas   2004     1       0       1      2
#
#    Athletes     GDP  Population
# 0         9  153.13    37299220
# 1        45  615.50    20091834
# 2         6  291.43     8175566
# 3         5    8.68     8105395
# 4        18    7.09      311981

# %%
xlsx = pd.ExcelFile('RawData/2008_Olympics.xlsx')
beijing_2008_df = pd.read_excel(xlsx)
beijing_2008_df.head()
# Out:
#          YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0  2008 Afghanistan    Afghanistan   2008     0       0       1      1
# 1      2008 Algeria        Algeria   2008     0       1       1      2
# 2    2008 Argentina      Argentina   2008     2       0       4      6
# 3      2008 Armenia        Armenia   2008     0       1       4      5
# 4    2008 Australia      Australia   2008    14      15      17     46
#
#    Athletes      GDP  Population
# 0         2    11.94    24485600
# 1        12   170.99    37100000
# 2        11   326.68    40117096
# 3         2    11.66     3268500
# 4        40  1061.58    22880619

# %%
xlsx = pd.ExcelFile('RawData/2012 Olympic coordinates.xlsx')
london_2012_df = pd.read_excel(xlsx)
london_2012_df.head()
# Out:
#        YearCountry      Country  Year  Gold  Silver  Bronze  Total  Athletes  \
# 0  2012Afghanistan  Afghanistan  2012     0       0       1      1         6
# 1      2012Algeria      Algeria  2012     1       0       0      1        42
# 2    2012Argentina    Argentina  2012     1       1       2      4       137
# 3      2012Armenia      Armenia  2012     0       1       2      3        25
# 4    2012Australia    Australia  2012     7      16      12     35       410
#
#    Population      GDP   Latitude   Longitude  Altitude(meters)
# 0    25500100    20.34  33.768006   66.238514              2148
# 1    37100000   188.68  28.000027    2.999983               709
# 2    40117096   445.99 -34.996496  -64.967282               270
# 3     3275700    10.25  40.769627   44.673665              2359
# 4    22823882  1371.76 -24.776109  134.755000               284

# %%
final_df = tokyo_2020_df.append(rio_2016_df)
final_df = final_df.append(london_2012_df)
final_df = final_df.append(beijing_2008_df)
final_df = final_df.append(athens_2004_df)
final_df = final_df.append(sydney_2000_df)
final_df
# Out:
#             YearCountry          Country  Year  Gold  Silver  Bronze  Total  \
# 0         2020Argentina        Argentina  2020     0       1       2      3
# 1           2020Armenia          Armenia  2020     0       2       2      4
# 2         2020Australia        Australia  2020    17       7      22     46
# 3           2020Austria          Austria  2020     1       1       5      7
# 4        2020Azerbaijan       Azerbaijan  2020     0       3       4      7
# ..                  ...              ...   ...   ...     ...     ...    ...
# 75  2000 United States    United States   2000    37      24      32     93
# 76        2000 Uruguay          Uruguay   2000     0       1       0      1
# 77     2000 Uzbekistan       Uzbekistan   2000     1       1       2      4
# 78        2000 Vietnam          Vietnam   2000     0       1       0      1
# 79     2000 Yugoslavia       Yugoslavia   2000     1       1       1      3
#
#     Athletes  Population      GDP  Latitude  Longitude  Altitude(meters)
# 0        174    45195774   637.43       NaN        NaN               NaN
# 1         17     2963243    11.54       NaN        NaN               NaN
# 2        478    25499884  1323.42       NaN        NaN               NaN
# 3         60     9006398   416.84       NaN        NaN               NaN
# 4         44    10139177    40.75       NaN        NaN               NaN
# ..       ...         ...      ...       ...        ...               ...
# 75       116   282224000  9898.80       NaN        NaN               NaN
# 76         4     3227565    22.82       NaN        NaN               NaN
# 77        22    24650000    13.76       NaN        NaN               NaN
# 78         2    77635400    31.17       NaN        NaN               NaN
# 79        24    10348473   120.00       NaN        NaN               NaN
#
# [506 rows x 13 columns]

# %%
xlsx = pd.ExcelFile('RawData/Olympic coordinates.xlsx')
coordinates_df = pd.read_excel(xlsx)
coordinates_df.head()
# Out:
#        Country   Latitude   Longitude  Altitude(meters)
# 0  Afghanistan  33.768006   66.238514              2148
# 1      Algeria  28.000027    2.999983               709
# 2    Argentina -34.996496  -64.967282               270
# 3      Armenia  40.769627   44.673665              2359
# 4    Australia -24.776109  134.755000               284

# %%
#final_df = final_df.merge(coordinates_df, left_on='Country', right_on='Country')
final_df
# Out:
#             YearCountry          Country  Year  Gold  Silver  Bronze  Total  \
# 0         2020Argentina        Argentina  2020     0       1       2      3
# 1           2020Armenia          Armenia  2020     0       2       2      4
# 2         2020Australia        Australia  2020    17       7      22     46
# 3           2020Austria          Austria  2020     1       1       5      7
# 4        2020Azerbaijan       Azerbaijan  2020     0       3       4      7
# ..                  ...              ...   ...   ...     ...     ...    ...
# 75  2000 United States    United States   2000    37      24      32     93
# 76        2000 Uruguay          Uruguay   2000     0       1       0      1
# 77     2000 Uzbekistan       Uzbekistan   2000     1       1       2      4
# 78        2000 Vietnam          Vietnam   2000     0       1       0      1
# 79     2000 Yugoslavia       Yugoslavia   2000     1       1       1      3
#
#     Athletes  Population      GDP  Latitude  Longitude  Altitude(meters)
# 0        174    45195774   637.43       NaN        NaN               NaN
# 1         17     2963243    11.54       NaN        NaN               NaN
# 2        478    25499884  1323.42       NaN        NaN               NaN
# 3         60     9006398   416.84       NaN        NaN               NaN
# 4         44    10139177    40.75       NaN        NaN               NaN
# ..       ...         ...      ...       ...        ...               ...
# 75       116   282224000  9898.80       NaN        NaN               NaN
# 76         4     3227565    22.82       NaN        NaN               NaN
# 77        22    24650000    13.76       NaN        NaN               NaN
# 78         2    77635400    31.17       NaN        NaN               NaN
# 79        24    10348473   120.00       NaN        NaN               NaN
#
# [506 rows x 13 columns]

# %%
final_df.to_csv ('final_df.csv', index = False, header=True)
final_df.to_excel ('final_df.xlsx', index = False, header=True)
