# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

xlsx = pd.ExcelFile('final_df.xlsx')
final_df = pd.read_excel(xlsx)
final_df
# Out:
#            YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0          2000Algeria        Algeria  2000     1       1       3      5
# 1        2000Argentina      Argentina  2000     0       2       2      4
# 2          2000Armenia        Armenia  2000     0       0       1      1
# 3        2000Australia      Australia  2000    16      25      17     58
# 4          2000Austria        Austria  2000     2       1       0      3
# ..                 ...            ...   ...   ...     ...     ...    ...
# 501         2020Uganda         Uganda  2020     2       1       1      4
# 502        2020Ukraine        Ukraine  2020     1       6      12     19
# 503  2020United States  United States  2020    39      41      33    113
# 504     2020Uzbekistan     Uzbekistan  2020     3       0       2      5
# 505      2020Venezuela      Venezuela  2020     1       3       0      4
#
#      Athletes  Population       GDP   Latitude   Longitude  Altitude(meters)  \
# 0          21    30950322     54.79  28.000027    2.999983               709
# 1          11    36858473    284.20 -34.996496  -64.967282               270
# 2           3     3169445      1.91  40.769627   44.673665              2359
# 3          82    19158366    416.89 -24.776109  134.755000               284
# 4          12     8011561    192.07  47.516232   14.550072              1568
# ..        ...         ...       ...        ...         ...               ...
# 501        21    45741007     26.00   1.533355   32.216658              1058
# 502       155    43733762    112.15  49.487197   31.271832               161
# 503       613   331002651  19485.39  39.783730 -100.445882               829
# 504        63    33469203     49.68  41.323730   63.952810               306
# 505        44    31108083    316.48   8.001871  -66.110932                66
#
#      Host
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
# ..    ...
# 501     0
# 502     0
# 503     0
# 504     0
# 505     0
#
# [506 rows x 14 columns]

# %%
inputs = ["Athletes", "Population", "GDP", 'Altitude(meters)', 'Host']
X = final_df[inputs]
y = final_df[["Total"]]
print(X.shape, y.shape)
# Out:
# (506, 5) (506, 1)

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X, y)
### END SOLUTION
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
from sklearn.neural_network import MLPRegressor


regr = MLPRegressor((20, 20, 20, 20), max_iter = 500).fit(X_train, np.array(y_train['Total']))

# %%
regr.score(X_test, y_test)
# Out:
# -47671.576307646

# %%
guessColName = 'guess_total'
final_df[guessColName]=regr.predict(final_df[inputs])

#reorder columns
d = {col : final_df[col] for col in final_df.columns if col != 'Total' and col != 'GuessedMedals'}
lastCols = ['Total', guessColName]
for col in lastCols:
    d[col] = final_df[col]
pd.DataFrame(d)
# Out:
#            YearCountry        Country  Year  Gold  Silver  Bronze  Athletes  \
# 0          2000Algeria        Algeria  2000     1       1       3        21
# 1        2000Argentina      Argentina  2000     0       2       2        11
# 2          2000Armenia        Armenia  2000     0       0       1         3
# 3        2000Australia      Australia  2000    16      25      17        82
# 4          2000Austria        Austria  2000     2       1       0        12
# ..                 ...            ...   ...   ...     ...     ...       ...
# 501         2020Uganda         Uganda  2020     2       1       1        21
# 502        2020Ukraine        Ukraine  2020     1       6      12       155
# 503  2020United States  United States  2020    39      41      33       613
# 504     2020Uzbekistan     Uzbekistan  2020     3       0       2        63
# 505      2020Venezuela      Venezuela  2020     1       3       0        44
#
#      Population       GDP   Latitude   Longitude  Altitude(meters)  Host  \
# 0      30950322     54.79  28.000027    2.999983               709     0
# 1      36858473    284.20 -34.996496  -64.967282               270     0
# 2       3169445      1.91  40.769627   44.673665              2359     0
# 3      19158366    416.89 -24.776109  134.755000               284     1
# 4       8011561    192.07  47.516232   14.550072              1568     0
# ..          ...       ...        ...         ...               ...   ...
# 501    45741007     26.00   1.533355   32.216658              1058     0
# 502    43733762    112.15  49.487197   31.271832               161     0
# 503   331002651  19485.39  39.783730 -100.445882               829     0
# 504    33469203     49.68  41.323730   63.952810               306     0
# 505    31108083    316.48   8.001871  -66.110932                66     0
#
#      guess_total  Total
# 0    -536.530692      5
# 1    -731.170335      4
# 2     272.315197      1
# 3    -386.120880     58
# 4      48.300463      3
# ..           ...    ...
# 501  -786.720232      4
# 502  -899.338470     19
# 503 -7808.604835    113
# 504  -651.733575      5
# 505  -649.855198      4
#
# [506 rows x 15 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
#model.fit(X_train_scaled, y_train_scaled)
model.fit(X_train_scaled, y_train)
### END SOLUTION
# Out:
# LinearRegression()

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
# Hint: You can predict values of X training and testing data using the model.predict() method on a fitted model

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
#model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), y_train_scaled - model.predict(X_train_scaled), c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), y_test - model.predict(X_test_scaled), c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
model.predict(X_test_scaled)
# Out:
# array([[ 7.31299466],
#        [ 5.68912699],
#        [20.73680762],
#        [ 5.9392352 ],
#        [14.56843651],
#        [ 5.67453186],
#        [ 8.30423269],
#        [ 9.34405529],
#        [ 5.92813227],
#        [ 5.90331442],
#        [ 6.03848007],
#        [ 7.06799385],
#        [13.81859787],
#        [ 5.97686048],
#        [22.27473152],
#        [ 5.72192099],
#        [ 8.09960111],
#        [ 8.6802279 ],
#        [35.6045919 ],
#        [ 5.24335178],
#        [40.7682971 ],
#        [18.10400467],
#        [ 6.43555334],
#        [ 5.4956061 ],
#        [ 8.27612319],
#        [ 4.44950632],
#        [ 6.86386372],
#        [10.29892638],
#        [ 4.25521784],
#        [ 9.78119548],
#        [ 7.0280485 ],
#        [ 9.2247522 ],
#        [ 7.38610946],
#        [13.51374436],
#        [ 6.76807798],
#        [ 4.72819065],
#        [ 3.23195199],
#        [ 8.78124257],
#        [ 6.18116243],
#        [ 6.48121852],
#        [ 9.51654221],
#        [ 5.61864531],
#        [ 5.76060579],
#        [ 7.24287426],
#        [11.87576407],
#        [ 7.42522869],
#        [ 7.98753061],
#        [ 5.87209006],
#        [16.42516385],
#        [ 5.89969878],
#        [ 5.83533168]])

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 141.08073836688018, R2: -714.8765058718112

# %%
model.predict(final_df[inputs])
# Out:
# array([[5.23873852e+07],
#        [6.23906845e+07],
#        [5.36317197e+06],
#        [3.24329290e+07],
#        [1.35618803e+07],
#        [1.36331959e+07],
#        [5.06710112e+05],
#        [4.55117300e+05],
#        [1.71388739e+07],
#        [1.73490170e+07],
#        [2.94282608e+08],
#        [1.32737218e+07],
#        [2.56245270e+07],
#        [5.21862777e+07],
#        [2.60869092e+07],
#        [2.13673234e+09],
#        [7.31108377e+07],
#        [5.99854497e+06],
#        [7.49707877e+06],
#        [1.88599658e+07],
#        [1.73899346e+07],
#        [9.03418302e+06],
#        [2.32222913e+06],
#        [1.08639069e+08],
#        [8.77744915e+06],
#        [9.99327070e+07],
#        [8.01104215e+06],
#        [1.38931178e+08],
#        [1.00927780e+08],
#        [1.82118747e+07],
#        [1.72427135e+07],
#        [4.80885075e+05],
#        [1.71957238e+09],
#        [3.59578051e+08],
#        [1.08862641e+08],
#        [6.43571045e+06],
#        [1.07413950e+07],
#        [9.67974229e+07],
#        [4.47574424e+06],
#        [2.14758555e+08],
#        [2.67577450e+07],
#        [5.15512604e+07],
#        [3.70676847e+06],
#        [8.31811849e+06],
#        [4.01504904e+06],
#        [6.09181358e+06],
#        [3.41908424e+06],
#        [1.68508377e+08],
#        [7.17797049e+06],
#        [5.01880292e+07],
#        [3.09940994e+07],
#        [2.69282624e+07],
#        [6.50866077e+06],
#        [2.11192400e+08],
#        [3.71357305e+07],
#        [7.59049442e+06],
#        [6.54178043e+07],
#        [1.73083974e+07],
#        [1.02676603e+06],
#        [3.75424334e+07],
#        [2.48362490e+08],
#        [3.65083824e+07],
#        [9.14548126e+06],
#        [3.34644015e+06],
#        [7.50452037e+07],
#        [7.86822379e+07],
#        [6.75222368e+07],
#        [3.26340644e+07],
#        [1.50170900e+07],
#        [1.21742119e+07],
#        [3.78315908e+07],
#        [1.05569930e+08],
#        [1.95558505e+06],
#        [1.12140358e+08],
#        [8.32235463e+07],
#        [4.77817897e+08],
#        [5.46327866e+06],
#        [4.17231041e+07],
#        [1.31407319e+08],
#        [1.75175252e+07],
#        [6.31351032e+07],
#        [3.40152510e+07],
#        [1.38406707e+07],
#        [1.37194788e+07],
#        [5.28204594e+05],
#        [1.65361031e+07],
#        [1.74984279e+07],
#        [3.05786861e+08],
#        [1.32507933e+07],
#        [2.81370485e+07],
#        [5.36108994e+07],
#        [2.71230914e+07],
#        [2.19694752e+09],
#        [7.38806493e+07],
#        [7.57600097e+06],
#        [1.90128487e+07],
#        [1.72990206e+07],
#        [9.14458580e+06],
#        [1.57839029e+07],
#        [1.26876957e+08],
#        [7.40531304e+06],
#        [2.28347583e+06],
#        [1.18417934e+08],
#        [8.87417382e+06],
#        [1.01891988e+08],
#        [7.96860653e+06],
#        [1.39617812e+08],
#        [1.01279510e+08],
#        [1.83170556e+07],
#        [1.17861551e+07],
#        [1.70741103e+07],
#        [1.82755922e+09],
#        [3.80067270e+08],
#        [1.13939603e+08],
#        [1.16340778e+07],
#        [9.84019086e+07],
#        [4.52822658e+06],
#        [2.16014305e+08],
#        [2.53157890e+07],
#        [5.66475036e+07],
#        [3.91496590e+06],
#        [5.87536323e+06],
#        [1.74372531e+08],
#        [4.63243638e+06],
#        [5.18491262e+07],
#        [2.75909561e+07],
#        [6.87111870e+06],
#        [2.32739179e+08],
#        [3.81874138e+07],
#        [7.76218179e+06],
#        [1.00275940e+07],
#        [6.48813036e+07],
#        [1.74149379e+07],
#        [3.81607433e+07],
#        [2.43466726e+08],
#        [1.36847215e+07],
#        [9.13351525e+06],
#        [3.38240417e+06],
#        [7.90534009e+07],
#        [8.15749656e+07],
#        [7.09049747e+07],
#        [1.46826664e+07],
#        [1.25358462e+07],
#        [3.11374730e+07],
#        [3.85170744e+07],
#        [1.11139976e+08],
#        [2.20283956e+06],
#        [1.19160668e+08],
#        [8.04646181e+07],
#        [6.09467227e+06],
#        [4.97255948e+08],
#        [4.39828338e+07],
#        [4.42244151e+07],
#        [2.16718454e+07],
#        [4.14435657e+07],
#        [6.27978387e+07],
#        [6.79068092e+07],
#        [5.53095034e+06],
#        [3.87410116e+07],
#        [1.43114658e+07],
#        [1.54222352e+07],
#        [5.98761992e+05],
#        [1.60148366e+07],
#        [1.85370253e+07],
#        [3.25626271e+08],
#        [1.24853191e+07],
#        [3.28473615e+07],
#        [5.88548398e+07],
#        [2.94739235e+07],
#        [2.28055182e+09],
#        [7.86673399e+07],
#        [7.26318406e+06],
#        [1.90278575e+07],
#        [1.77821966e+07],
#        [9.44988876e+06],
#        [1.58752158e+07],
#        [2.45156798e+07],
#        [1.38673066e+08],
#        [2.23118033e+06],
#        [1.42722228e+08],
#        [9.15535134e+06],
#        [1.10647093e+08],
#        [7.56365728e+06],
#        [1.38552703e+08],
#        [1.05417950e+08],
#        [1.82631227e+07],
#        [1.68637247e+07],
#        [5.40581679e+05],
#        [2.04841111e+09],
#        [4.02242533e+08],
#        [1.29165367e+08],
#        [7.76931878e+06],
#        [1.33051739e+07],
#        [1.02899177e+08],
#        [4.57983558e+06],
#        [2.16121235e+08],
#        [2.82987904e+07],
#        [6.53524672e+07],
#        [9.26983800e+06],
#        [3.50477371e+06],
#        [5.40477856e+06],
#        [4.79610793e+07],
#        [2.17663030e+06],
#        [1.90155608e+08],
#        [6.02491014e+06],
#        [4.63127424e+06],
#        [5.50553606e+07],
#        [2.83311514e+07],
#        [7.50410926e+06],
#        [2.75003678e+08],
#        [4.07104538e+07],
#        [8.47771617e+06],
#        [5.76454715e+06],
#        [6.51740620e+07],
#        [1.78796643e+07],
#        [3.22346044e+07],
#        [2.42160082e+08],
#        [3.16000153e+05],
#        [1.20541410e+07],
#        [8.77521208e+06],
#        [9.21700745e+06],
#        [3.48553862e+06],
#        [8.56347081e+07],
#        [8.22466529e+07],
#        [7.81932684e+07],
#        [5.22973680e+07],
#        [1.60701513e+07],
#        [1.33257385e+07],
#        [3.93810021e+07],
#        [1.28888985e+07],
#        [1.10835085e+08],
#        [1.04790778e+07],
#        [2.23079950e+06],
#        [1.80672223e+07],
#        [1.26487839e+08],
#        [7.72608920e+07],
#        [5.30609058e+08],
#        [4.92950142e+07],
#        [4.59585922e+07],
#        [1.48680551e+08],
#        [2.15870647e+07],
#        [4.31608404e+07],
#        [6.27981304e+07],
#        [6.79085817e+07],
#        [5.54317889e+06],
#        [3.86496940e+07],
#        [1.56324273e+07],
#        [5.98771749e+05],
#        [2.08995451e+06],
#        [1.60131703e+07],
#        [1.83542630e+07],
#        [3.42697490e+06],
#        [3.28308834e+08],
#        [1.24660031e+07],
#        [5.92260697e+07],
#        [2.28057257e+09],
#        [7.93073738e+07],
#        [7.26652628e+06],
#        [1.90394490e+07],
#        [1.42070712e+06],
#        [1.77855658e+07],
#        [9.45947532e+06],
#        [1.59914106e+07],
#        [1.40295290e+08],
#        [2.19337171e+06],
#        [1.42723670e+08],
#        [9.18202642e+06],
#        [1.07231452e+08],
#        [2.68089747e+06],
#        [7.61267376e+06],
#        [1.38552764e+08],
#        [1.05430437e+08],
#        [1.82891722e+07],
#        [1.90674870e+05],
#        [2.49046015e+07],
#        [1.20238886e+07],
#        [1.68579436e+07],
#        [2.04839868e+09],
#        [4.02258184e+08],
#        [1.27210227e+08],
#        [7.76653330e+06],
#        [1.02997894e+08],
#        [6.30471997e+06],
#        [2.15860305e+08],
#        [2.85323347e+07],
#        [6.53544910e+07],
#        [6.06329380e+06],
#        [3.50651926e+06],
#        [5.38367195e+06],
#        [5.00513143e+07],
#        [1.90146108e+08],
#        [6.03822143e+06],
#        [4.63244465e+06],
#        [1.04850165e+06],
#        [5.54178494e+07],
#        [2.83780959e+07],
#        [7.53755727e+06],
#        [4.15620520e+07],
#        [8.54807321e+06],
#        [6.52368162e+07],
#        [1.78831781e+07],
#        [6.27670677e+06],
#        [2.97561236e+06],
#        [3.22347924e+07],
#        [2.42555347e+08],
#        [4.80526195e+07],
#        [1.20593815e+07],
#        [8.99198835e+06],
#        [9.21988043e+06],
#        [3.49056154e+06],
#        [8.76283095e+07],
#        [8.46432856e+07],
#        [7.81506670e+07],
#        [1.61658711e+07],
#        [1.35476486e+07],
#        [3.93913088e+07],
#        [1.32078461e+07],
#        [1.10829807e+08],
#        [2.23461819e+06],
#        [1.80671782e+07],
#        [1.26480581e+08],
#        [5.77800838e+07],
#        [7.71163336e+07],
#        [5.32904173e+08],
#        [4.94779020e+07],
#        [4.89952748e+07],
#        [3.28510410e+07],
#        [1.48679509e+08],
#        [6.71420611e+07],
#        [7.34955103e+07],
#        [5.10652727e+06],
#        [4.02696482e+07],
#        [1.45790494e+07],
#        [1.63368603e+07],
#        [6.56954959e+05],
#        [2.33160477e+06],
#        [1.61027601e+07],
#        [1.91081559e+07],
#        [3.51829332e+08],
#        [1.21501249e+07],
#        [1.89206828e+07],
#        [6.07027883e+07],
#        [2.32108714e+09],
#        [8.16366113e+07],
#        [7.15105865e+06],
#        [1.92796177e+07],
#        [1.78614789e+07],
#        [9.61122159e+06],
#        [1.78213351e+07],
#        [1.54892533e+08],
#        [2.22107480e+06],
#        [1.68230043e+08],
#        [1.51025806e+06],
#        [9.28186032e+06],
#        [1.13111462e+08],
#        [6.22625831e+06],
#        [1.37843222e+08],
#        [1.10289803e+08],
#        [1.83225105e+07],
#        [1.80583812e+05],
#        [1.66651197e+07],
#        [2.21913465e+09],
#        [4.35968066e+08],
#        [1.33920575e+08],
#        [7.85849809e+06],
#        [1.41884986e+07],
#        [1.02937213e+08],
#        [3.84253720e+07],
#        [4.61394996e+06],
#        [2.14942687e+08],
#        [1.28547195e+07],
#        [2.96979440e+07],
#        [7.79464350e+07],
#        [3.00859973e+06],
#        [6.69874143e+06],
#        [4.92649407e+06],
#        [5.13419915e+07],
#        [2.15005281e+08],
#        [5.00778034e+06],
#        [5.81880963e+07],
#        [2.86768335e+07],
#        [7.78114859e+06],
#        [3.36812356e+07],
#        [3.08404152e+08],
#        [4.25775681e+07],
#        [8.79900538e+06],
#        [1.70449348e+08],
#        [6.43250353e+07],
#        [1.75187158e+07],
#        [5.88180580e+06],
#        [3.78568739e+06],
#        [3.35707862e+07],
#        [2.43917326e+08],
#        [1.20148565e+07],
#        [9.37225955e+06],
#        [9.18147993e+06],
#        [3.49338390e+06],
#        [9.30245251e+07],
#        [8.56924565e+07],
#        [7.85835279e+07],
#        [1.65920620e+07],
#        [1.40340882e+07],
#        [3.99831095e+07],
#        [1.43545069e+07],
#        [1.15034222e+08],
#        [2.30249137e+06],
#        [1.88019423e+07],
#        [1.33159475e+08],
#        [7.65049376e+07],
#        [1.55037957e+07],
#        [5.44259841e+08],
#        [5.29789433e+07],
#        [5.26577734e+07],
#        [1.55221794e+08],
#        [7.65072720e+07],
#        [5.01430333e+06],
#        [4.31787332e+07],
#        [1.52486155e+07],
#        [1.71623872e+07],
#        [6.65808431e+05],
#        [2.88063015e+06],
#        [1.59949262e+07],
#        [1.96230618e+07],
#        [1.08296719e+05],
#        [3.98001293e+06],
#        [3.59807736e+08],
#        [1.17616654e+07],
#        [3.53812629e+07],
#        [6.39037992e+07],
#        [2.43637584e+09],
#        [8.61292173e+07],
#        [6.94941219e+06],
#        [1.91730023e+07],
#        [1.78618699e+07],
#        [9.80828321e+06],
#        [1.83623337e+07],
#        [2.98642894e+07],
#        [1.73216245e+08],
#        [2.24570015e+06],
#        [1.94589167e+08],
#        [1.51748771e+06],
#        [9.38140976e+06],
#        [1.10515492e+08],
#        [6.75124346e+06],
#        [1.41860087e+08],
#        [5.25953583e+07],
#        [1.10284645e+08],
#        [1.76443846e+07],
#        [1.90230181e+05],
#        [1.26937248e+07],
#        [1.63533454e+07],
#        [2.33585406e+09],
#        [4.62983798e+08],
#        [1.42172929e+08],
#        [8.36202643e+06],
#        [1.46549594e+07],
#        [1.02362920e+08],
#        [4.46487650e+07],
#        [5.01205833e+06],
#        [2.14136483e+08],
#        [1.72701107e+07],
#        [3.17839450e+07],
#        [9.10153217e+07],
#        [3.14681140e+06],
#        [7.22984465e+06],
#        [1.10413825e+07],
#        [3.19304339e+06],
#        [4.60844488e+06],
#        [3.51791445e+06],
#        [5.47866773e+07],
#        [2.18247729e+08],
#        [6.82803604e+06],
#        [5.54798620e+06],
#        [6.24757124e+07],
#        [4.30006481e+06],
#        [2.90136257e+07],
#        [8.16501350e+06],
#        [3.48920104e+08],
#        [9.18057654e+06],
#        [1.85482929e+08],
#        [6.40667786e+07],
#        [1.72617888e+07],
#        [5.88129783e+06],
#        [4.87857990e+06],
#        [3.25646115e+07],
#        [5.72379365e+04],
#        [5.89345506e+07],
#        [1.47892779e+07],
#        [9.24179967e+06],
#        [3.51911340e+06],
#        [1.00390935e+08],
#        [8.67982187e+07],
#        [7.91545462e+07],
#        [1.71009547e+07],
#        [1.46564775e+07],
#        [3.13179606e+07],
#        [3.97990066e+07],
#        [1.18150389e+08],
#        [2.00050561e+07],
#        [1.42763743e+08],
#        [1.02089549e+07],
#        [7.74218083e+07],
#        [7.40262800e+07],
#        [5.60499379e+08],
#        [5.66511995e+07],
#        [5.26580724e+07]])
