# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

xlsx = pd.ExcelFile('final_df.xlsx')
final_df = pd.read_excel(xlsx)
final_df
# Out:
#            YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0          2000Armenia        Armenia  2000     0       0       1      1
# 1         2000Barbados       Barbados  2000     0       0       1      1
# 2         2000Cameroon       Cameroon  2000     1       0       0      1
# 3            2000Chile          Chile  2000     0       0       1      1
# 4         2000Colombia       Colombia  2000     1       0       0      1
# ..                 ...            ...   ...   ...     ...     ...    ...
# 501  2004United States  United States  2004    36      39      26    101
# 502  2012United States  United States  2012    46      29      29    104
# 503  2008United States  United States  2008    36      39      37    112
# 504  2020United States  United States  2020    39      41      33    113
# 505  2016United States  United States  2016    46      37      38    121
#
#      Athletes  Population       GDP   Latitude   Longitude  Altitude(meters)  \
# 0           3     3169445      1.91  40.769627   44.673665              2359
# 1          11      268906      2.56  13.193887  -59.543198               168
# 2          11    15139138     10.08   4.612552   13.153811               667
# 3           7    15411830     75.21 -31.761336  -71.318770               610
# 4          11    43193863     15.95   2.889443  -73.783892               255
# ..        ...         ...       ...        ...         ...               ...
# 501       140   293694333  11797.80  39.783730 -100.445882               829
# 502        54    29123400  15094.00  39.783730 -100.445882               829
# 503       121   313382000  14219.30  39.783730 -100.445882               829
# 504       613   331002651  19485.39  39.783730 -100.445882               829
# 505       554   321418820  18036.65  39.783730 -100.445882               829
#
#      Host  Bins
# 0       0     1
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1
# ..    ...   ...
# 501     0     4
# 502     0     4
# 503     0     4
# 504     0     4
# 505     0     4
#
# [506 rows x 15 columns]

# %%
inputs = ["Athletes", "GDP", 'Altitude(meters)', 'Host']
X = final_df[inputs]
y = final_df[["Bins"]]
print(X.shape, y.shape)
# Out:
# (506, 4) (506, 1)

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X, y)
### END SOLUTION
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
from sklearn.neural_network import MLPRegressor


regr = MLPRegressor((20, 20, 20, 20), max_iter = 500).fit(X_train, np.array(y_train['Bins']))

# %%
regr.score(X_test, y_test)
# Out:
# -3.6146368123959984

# %%
guessColName = 'guess_total'
final_df[guessColName]=regr.predict(final_df[inputs])

#reorder columns
d = {col : final_df[col] for col in final_df.columns if col != 'Total' and col != 'GuessedMedals'}
lastCols = ['Total', guessColName]
for col in lastCols:
    d[col] = final_df[col]
pd.DataFrame(d)
# Out:
#            YearCountry        Country  Year  Gold  Silver  Bronze  Athletes  \
# 0          2000Armenia        Armenia  2000     0       0       1         3
# 1         2000Barbados       Barbados  2000     0       0       1        11
# 2         2000Cameroon       Cameroon  2000     1       0       0        11
# 3            2000Chile          Chile  2000     0       0       1         7
# 4         2000Colombia       Colombia  2000     1       0       0        11
# ..                 ...            ...   ...   ...     ...     ...       ...
# 501  2004United States  United States  2004    36      39      26       140
# 502  2012United States  United States  2012    46      29      29        54
# 503  2008United States  United States  2008    36      39      37       121
# 504  2020United States  United States  2020    39      41      33       613
# 505  2016United States  United States  2016    46      37      38       554
#
#      Population       GDP   Latitude   Longitude  Altitude(meters)  Host  \
# 0       3169445      1.91  40.769627   44.673665              2359     0
# 1        268906      2.56  13.193887  -59.543198               168     0
# 2      15139138     10.08   4.612552   13.153811               667     0
# 3      15411830     75.21 -31.761336  -71.318770               610     0
# 4      43193863     15.95   2.889443  -73.783892               255     0
# ..          ...       ...        ...         ...               ...   ...
# 501   293694333  11797.80  39.783730 -100.445882               829     0
# 502    29123400  15094.00  39.783730 -100.445882               829     0
# 503   313382000  14219.30  39.783730 -100.445882               829     0
# 504   331002651  19485.39  39.783730 -100.445882               829     0
# 505   321418820  18036.65  39.783730 -100.445882               829     0
#
#      Bins  guess_total  Total
# 0       1    -0.040138      1
# 1       1     0.350221      1
# 2       1     0.388941      1
# 3       1     0.120797      1
# 4       1     0.204588      1
# ..    ...          ...    ...
# 501     4    -2.234834    101
# 502     4    -1.491819    104
# 503     4    -2.536231    112
# 504     4    -2.638763    113
# 505     4    -4.386740    121
#
# [506 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
#model.fit(X_train_scaled, y_train_scaled)
model.fit(X_train_scaled, y_train)
### END SOLUTION
# Out:
# LinearRegression()

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
# Hint: You can predict values of X training and testing data using the model.predict() method on a fitted model

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
#model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), y_train_scaled - model.predict(X_train_scaled), c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), y_test - model.predict(X_test_scaled), c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
model.predict(X_test_scaled)
# Out:
# array([[1.13378286],
#        [1.2242614 ],
#        [2.25852447],
#        [1.15860361],
#        [1.57513849],
#        [1.3446632 ],
#        [1.01281286],
#        [1.27516745],
#        [2.09586816],
#        [1.81335912],
#        [1.50081121],
#        [1.20720731],
#        [2.04516419],
#        [1.36385071],
#        [1.32392318],
#        [2.37166843],
#        [1.25912638],
#        [1.34501231],
#        [1.59721824],
#        [1.30449593],
#        [1.73454261],
#        [1.31184753],
#        [1.23481372],
#        [3.32483424],
#        [1.32595891],
#        [2.29292043],
#        [1.24192034],
#        [1.9742563 ],
#        [1.12760087],
#        [1.37032746],
#        [1.43968752],
#        [1.31035551],
#        [1.44228539],
#        [1.26407118],
#        [1.17552322],
#        [1.29994307],
#        [1.16152924],
#        [1.46477339],
#        [1.24993853],
#        [1.16730481],
#        [3.72923936],
#        [1.24647222],
#        [1.1946979 ],
#        [1.29470649],
#        [1.18116253],
#        [1.19855098],
#        [1.16115426],
#        [1.34197459],
#        [2.26997987],
#        [0.94655778],
#        [1.27016958]])

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 2.395882682285525, R2: -0.1708033314073807

# %%
model.predict(final_df[inputs])
# Out:
# array([[-1.76231348e+02],
#        [-8.63472634e+00],
#        [-4.41158615e+01],
#        [-2.03646142e+01],
#        [-1.10870898e+01],
#        [ 8.37763346e+01],
#        [-2.03136762e+01],
#        [ 3.36128507e+01],
#        [ 3.32069014e+02],
#        [-9.92393362e+00],
#        [-1.97543643e+02],
#        [ 1.49861453e+02],
#        [ 1.14317580e+02],
#        [ 1.16718000e+01],
#        [ 1.84119008e+01],
#        [ 2.16143203e+00],
#        [-1.88665098e+01],
#        [-4.28786756e+01],
#        [ 1.08150054e+01],
#        [-7.74670538e+01],
#        [ 2.39167619e+01],
#        [ 7.19435896e+00],
#        [-1.17117107e+02],
#        [ 7.31948397e+01],
#        [ 7.78843630e+01],
#        [ 9.03262586e+00],
#        [ 4.68669863e+01],
#        [-1.57319919e+02],
#        [-3.22630468e+01],
#        [ 4.20707862e+02],
#        [ 1.18766526e+01],
#        [-5.82720243e+01],
#        [ 5.24425858e+01],
#        [ 6.28009644e+00],
#        [-3.01955851e+01],
#        [-4.63015777e+00],
#        [-4.87423334e+01],
#        [ 1.64910203e+01],
#        [ 2.89624488e+01],
#        [ 1.99134353e+02],
#        [ 1.11536969e+02],
#        [-2.58813314e+01],
#        [ 1.29200990e+01],
#        [ 9.46329307e+01],
#        [-3.44548665e-01],
#        [-1.54023716e+02],
#        [ 1.33318268e+01],
#        [ 7.45365817e+00],
#        [ 8.73130589e+00],
#        [-6.85385602e+01],
#        [ 8.29742645e+00],
#        [-1.38656778e+01],
#        [-2.91263939e+01],
#        [-2.64109048e+01],
#        [-5.37531913e+01],
#        [ 9.48422927e+01],
#        [ 5.15850790e+01],
#        [-5.64858856e+01],
#        [-8.72701231e+01],
#        [ 4.75779982e+01],
#        [ 1.39965875e+02],
#        [-2.42879469e+02],
#        [-3.21276662e+01],
#        [ 9.99775291e+01],
#        [-2.51000828e+01],
#        [ 1.15205558e+01],
#        [-1.18143407e+02],
#        [ 1.15151376e+01],
#        [ 1.17219043e+01],
#        [ 1.16681305e+01],
#        [ 7.40832732e+01],
#        [-2.86353622e+01],
#        [-3.75980854e+01],
#        [-3.59335290e+01],
#        [-1.09352348e+02],
#        [-5.52938234e+01],
#        [ 1.08272980e+02],
#        [ 9.40515955e+01],
#        [ 4.73657038e+01],
#        [ 3.12310533e+00],
#        [ 5.56591668e+01],
#        [ 9.32097232e+01],
#        [-2.47715847e+02],
#        [ 1.42580188e+01],
#        [ 1.17737112e+02],
#        [ 1.64119157e+01],
#        [ 4.04000912e+00],
#        [-6.70323157e+01],
#        [-1.70757866e+01],
#        [ 1.42608605e+01],
#        [-2.85889955e+01],
#        [ 3.19785796e-01],
#        [ 2.80105641e+01],
#        [ 1.75625492e+01],
#        [-2.56720829e+01],
#        [-2.93770649e+00],
#        [-1.06201225e+02],
#        [-9.98823398e+01],
#        [-1.03446800e+01],
#        [ 1.58725670e+02],
#        [-1.02607981e+01],
#        [ 6.87329843e+00],
#        [-6.35423847e+01],
#        [ 4.58705749e+00],
#        [ 4.59319227e+00],
#        [-2.10520113e+01],
#        [-4.78243772e+01],
#        [-9.83374656e+00],
#        [ 6.52102910e+00],
#        [ 6.18778076e+00],
#        [-2.99401362e+00],
#        [ 6.33271359e+02],
#        [ 5.26751268e+02],
#        [-4.21213793e+01],
#        [-3.84030616e+01],
#        [ 3.20118460e+01],
#        [ 2.61614761e+00],
#        [ 6.54635010e+00],
#        [ 1.22233703e+01],
#        [ 6.01961426e-01],
#        [ 3.33907516e+01],
#        [ 6.73842930e+00],
#        [ 6.42866037e+00],
#        [-1.16838015e+02],
#        [ 5.23821280e+01],
#        [-2.49421940e+02],
#        [ 1.40624071e+01],
#        [ 1.66370180e+00],
#        [ 2.23473260e+01],
#        [ 5.90841600e+01],
#        [ 9.88618751e+00],
#        [ 2.89482988e+01],
#        [ 2.72413491e+02],
#        [ 1.64852414e+01],
#        [ 4.08854421e+01],
#        [-1.53783689e+00],
#        [-1.47175940e+01],
#        [ 6.96067331e+01],
#        [ 8.06626136e+01],
#        [ 1.13068692e+02],
#        [ 1.04289960e+01],
#        [ 8.48098260e+00],
#        [ 1.56074859e+01],
#        [ 5.92656222e+02],
#        [ 9.05710021e+01],
#        [ 9.03576547e+01],
#        [-4.20681245e+00],
#        [ 2.43501468e+01],
#        [-1.23920459e+02],
#        [ 3.50157190e+01],
#        [ 7.40514295e+00],
#        [ 1.09057183e+01],
#        [ 8.01470641e+00],
#        [ 7.58258617e+01],
#        [-3.57603517e+01],
#        [-3.51954924e+01],
#        [ 1.20957976e+01],
#        [ 3.94318282e+01],
#        [ 7.16942755e+01],
#        [ 1.42492803e+02],
#        [ 2.17162564e+01],
#        [-5.59480554e+01],
#        [ 3.70670582e+00],
#        [ 6.12777258e+00],
#        [ 3.11129710e-01],
#        [ 3.41474081e+00],
#        [-4.18519152e+01],
#        [ 3.44440945e+01],
#        [ 3.88812578e+01],
#        [ 1.05416120e+02],
#        [-1.47460414e+01],
#        [ 2.63833382e+00],
#        [ 2.40872622e+02],
#        [ 4.43870844e+01],
#        [-1.28292226e+00],
#        [-7.57063295e+01],
#        [ 1.11313598e+01],
#        [ 6.00974577e+01],
#        [ 4.59213374e+01],
#        [ 3.05310966e+02],
#        [ 7.37034064e+01],
#        [-1.98899903e+02],
#        [ 1.01144640e+01],
#        [-3.65348662e+00],
#        [-1.69805194e+02],
#        [ 1.68703384e+02],
#        [ 1.32557295e+02],
#        [ 1.06499728e+02],
#        [ 3.24638499e+01],
#        [-1.45845599e+00],
#        [ 1.05599440e+02],
#        [ 2.72708161e+02],
#        [ 1.45153918e+02],
#        [ 2.23153956e+01],
#        [ 9.90214213e+01],
#        [ 2.08394482e+02],
#        [ 3.26075445e+01],
#        [-1.96227771e+02],
#        [ 5.25188679e+01],
#        [-2.50485031e+01],
#        [ 4.60047809e+01],
#        [ 7.06956276e+01],
#        [ 4.06596470e+02],
#        [-6.88397872e+01],
#        [-1.27087292e+01],
#        [-7.51823113e+01],
#        [-1.37038663e+01],
#        [ 7.08424246e+02],
#        [ 5.21841253e+01],
#        [ 6.85206069e+00],
#        [-8.26842418e+01],
#        [ 1.66398393e+01],
#        [ 7.99820027e+01],
#        [ 2.54317315e+02],
#        [-1.32983800e+02],
#        [ 1.36449847e+03],
#        [-1.10760131e+01],
#        [-7.59610780e+01],
#        [ 1.42746264e+02],
#        [ 1.22095752e+02],
#        [-3.90138965e+01],
#        [-2.45551330e+01],
#        [-1.70539436e+01],
#        [ 8.45678316e+01],
#        [ 2.28449230e+01],
#        [ 4.46005197e+00],
#        [ 1.98443838e+02],
#        [-1.68319310e+02],
#        [ 2.01413395e+01],
#        [ 6.41387255e+01],
#        [ 3.57729547e+01],
#        [-2.97025082e+01],
#        [-3.03412883e+01],
#        [-1.70805773e+02],
#        [-1.43647309e+02],
#        [ 1.21537838e+01],
#        [ 1.12146640e+02],
#        [ 1.14349804e+02],
#        [ 2.96417529e+02],
#        [-1.24016284e+02],
#        [ 1.01638803e+02],
#        [ 5.36684873e+01],
#        [ 4.69607741e+01],
#        [-2.88675017e+01],
#        [-6.70689084e+01],
#        [ 1.01901611e+02],
#        [-3.17283597e+01],
#        [ 6.39633958e+01],
#        [-4.59821224e-02],
#        [-1.43347954e+02],
#        [-5.66216096e+01],
#        [ 7.61017936e+01],
#        [-2.40366919e+00],
#        [-1.25512572e+01],
#        [ 4.93569260e+00],
#        [ 6.42082856e+00],
#        [-1.69455022e+01],
#        [ 1.40302865e+03],
#        [ 1.45818518e+00],
#        [-4.71742554e+01],
#        [-1.10110449e+02],
#        [ 2.79867735e+00],
#        [-1.61627114e+01],
#        [-1.73392428e+02],
#        [ 4.87632820e+02],
#        [ 1.58729211e+01],
#        [ 1.34498260e+01],
#        [ 1.43213064e+01],
#        [ 3.33980507e+01],
#        [ 1.44860460e+02],
#        [ 1.32554549e+02],
#        [ 1.06422461e+02],
#        [ 1.41516407e+01],
#        [-1.26652599e+02],
#        [ 1.45943982e+02],
#        [ 3.40847364e+01],
#        [ 2.87401092e+02],
#        [ 9.16807777e+01],
#        [ 1.93578941e+01],
#        [ 3.20153685e+02],
#        [-2.98859518e+01],
#        [ 4.57099773e+00],
#        [ 3.83344154e+00],
#        [ 4.48614216e+02],
#        [ 3.35625086e+01],
#        [-8.37752027e+01],
#        [ 2.98305502e+01],
#        [-5.96851815e+01],
#        [-6.23049344e+01],
#        [-5.30369904e+01],
#        [ 1.37023971e+02],
#        [ 8.38266842e+01],
#        [ 1.68279519e+01],
#        [ 1.59448907e+02],
#        [-1.20402233e+02],
#        [-4.55672452e+01],
#        [ 8.05895362e+01],
#        [ 3.14913614e+01],
#        [ 4.99558781e+02],
#        [-1.10257072e+02],
#        [ 7.67758064e+01],
#        [ 1.50032715e+02],
#        [ 1.17057037e+01],
#        [ 1.26004927e+02],
#        [-5.53630796e-01],
#        [ 7.83810272e+01],
#        [ 1.04951811e+02],
#        [-2.29696668e+00],
#        [-4.98516543e+00],
#        [-2.62842361e+01],
#        [-1.12032793e+02],
#        [-1.30911432e+01],
#        [ 1.02038504e+02],
#        [ 4.72217787e+01],
#        [ 1.08200034e+02],
#        [-1.61888850e+02],
#        [-1.30537091e+02],
#        [ 2.56551529e+01],
#        [-1.55423991e+02],
#        [-6.18343278e+01],
#        [ 2.72948742e+02],
#        [-1.23703518e+02],
#        [-1.16974126e+02],
#        [ 1.05925003e+02],
#        [ 2.19269314e+01],
#        [ 2.16706443e+01],
#        [ 2.26960739e+01],
#        [ 1.64569084e+02],
#        [ 7.65714444e+02],
#        [ 5.27249479e+01],
#        [ 2.59656605e+01],
#        [-1.33001640e+02],
#        [ 9.06542224e+00],
#        [-1.76764614e+00],
#        [ 4.48046405e+01],
#        [ 1.03466317e+02],
#        [ 1.71394033e+02],
#        [ 9.80565209e+01],
#        [-1.49876443e+02],
#        [ 4.04783863e+02],
#        [-2.74563703e+01],
#        [ 1.44095677e+02],
#        [ 1.98998935e+01],
#        [-1.24934653e+02],
#        [ 5.60259067e+01],
#        [ 7.04032703e+01],
#        [ 1.42598583e+03],
#        [-1.65709578e+01],
#        [ 5.42309478e+01],
#        [ 3.39787476e+01],
#        [ 1.38228479e+01],
#        [ 7.56744429e+01],
#        [ 2.84422597e+01],
#        [ 1.10335315e+02],
#        [ 9.56384336e+01],
#        [ 2.62407718e+01],
#        [-3.06894189e+01],
#        [-2.91100457e+01],
#        [ 1.76212402e+02],
#        [-1.11588085e+01],
#        [ 1.89918120e+02],
#        [ 5.93676906e+01],
#        [ 4.23984002e+01],
#        [ 3.02462688e+01],
#        [ 5.85776425e+01],
#        [ 1.64944450e+02],
#        [ 2.27945147e+01],
#        [ 4.78864183e+01],
#        [ 2.84055941e+01],
#        [ 1.64262377e+01],
#        [-1.86587440e+01],
#        [ 2.76724797e+01],
#        [-3.19843934e+01],
#        [ 1.66576630e+02],
#        [-1.06254366e+01],
#        [ 4.95353307e+01],
#        [-2.77016588e+01],
#        [ 1.82410555e+02],
#        [ 1.66999531e+02],
#        [ 5.42362359e+01],
#        [ 5.89274756e+01],
#        [ 1.21710871e+02],
#        [ 1.80703040e+02],
#        [ 6.69123502e+01],
#        [-1.45839279e+01],
#        [ 2.79457026e+02],
#        [-6.08673462e+01],
#        [ 1.19049475e+01],
#        [ 1.20590104e+02],
#        [-1.80608952e+01],
#        [-4.32806507e+01],
#        [ 2.86954125e+00],
#        [ 3.41009296e+01],
#        [ 5.51851340e+01],
#        [ 2.09944269e+01],
#        [ 1.22233956e+01],
#        [ 1.10657647e+01],
#        [ 1.08803369e+02],
#        [ 1.86289194e+02],
#        [ 1.99102346e+02],
#        [ 3.48188663e+01],
#        [ 3.36082579e+00],
#        [ 2.12368023e+01],
#        [ 1.91908417e+02],
#        [ 1.13933555e+02],
#        [ 5.68375038e+01],
#        [ 4.19975915e+01],
#        [-2.24786045e+00],
#        [-7.03585167e+00],
#        [ 2.73155765e+02],
#        [-2.44421707e+00],
#        [ 3.86985143e-01],
#        [ 2.21099316e+02],
#        [ 1.42282021e+02],
#        [ 7.88959827e+02],
#        [ 4.90287602e+01],
#        [ 4.50413639e+02],
#        [ 3.90316007e+02],
#        [ 4.28389940e+02],
#        [-6.46892496e+01],
#        [ 5.74624219e+02],
#        [ 2.75717144e+01],
#        [ 6.45958861e+01],
#        [ 6.01955101e+01],
#        [ 1.51388399e+02],
#        [-6.46846071e+00],
#        [ 4.67444824e+02],
#        [ 6.08263805e+02],
#        [ 2.75779532e+02],
#        [ 5.09591274e+01],
#        [ 9.04935636e+01],
#        [-1.88648717e+01],
#        [ 2.92211778e+02],
#        [ 1.32966658e+02],
#        [ 6.34633746e+01],
#        [ 7.37874060e+01],
#        [ 4.90374447e+02],
#        [ 4.37695068e+02],
#        [ 6.65883445e+02],
#        [ 3.74967481e+01],
#        [ 1.86808543e+01],
#        [ 5.63616778e+01],
#        [ 5.02937786e+02],
#        [ 8.28852562e+00],
#        [ 5.42587102e+02],
#        [ 1.90539501e+01],
#        [ 1.42807893e+03],
#        [ 4.81020855e+01],
#        [ 4.22200913e+01],
#        [ 6.60870140e+02],
#        [ 3.87943572e+01],
#        [ 1.57588485e+02],
#        [ 6.26951132e+02],
#        [ 3.70293892e+02],
#        [ 5.57753236e+02],
#        [ 2.41169105e+01],
#        [ 6.83478390e+01],
#        [ 3.01971172e+02],
#        [ 2.64842991e+01],
#        [-4.76403674e+01],
#        [ 4.71421192e+02],
#        [-2.35228360e+00],
#        [ 8.53289304e+02],
#        [-4.92109882e+01],
#        [ 8.46765525e+02],
#        [ 4.75603959e+02],
#        [ 3.06195424e+02],
#        [-5.68298212e+01],
#        [ 1.19111421e+03],
#        [-4.39147689e+00],
#        [ 1.75620446e+03],
#        [ 6.05715098e+02],
#        [ 1.10455891e+03],
#        [ 1.25632932e+03],
#        [ 8.02875033e+02],
#        [ 1.08918470e+03],
#        [ 8.69126914e+02],
#        [ 1.17349510e+03],
#        [ 3.15004626e+02],
#        [ 4.72555835e+02],
#        [ 6.70691145e+02],
#        [ 1.77990751e+02],
#        [ 8.12691423e+02],
#        [ 4.42978250e+02],
#        [ 4.10323534e+02],
#        [ 1.23140914e+02],
#        [ 2.28043085e+02],
#        [ 1.52540632e+03],
#        [ 4.87575242e+02],
#        [ 4.59222195e+02],
#        [ 7.57635352e+02],
#        [ 8.05141771e+02],
#        [ 9.35200841e+02],
#        [ 3.32788778e+03],
#        [ 5.33577571e+02],
#        [ 2.12715236e+03],
#        [ 3.70686432e+03],
#        [ 3.33109612e+01],
#        [-1.39542751e+01],
#        [ 3.01869387e+03],
#        [-7.98245279e+01],
#        [ 3.60989461e+03],
#        [ 4.61374511e+03],
#        [ 4.35508469e+03],
#        [ 6.06895262e+03],
#        [ 5.61081035e+03]])
