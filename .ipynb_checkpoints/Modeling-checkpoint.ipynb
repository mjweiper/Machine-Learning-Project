# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

xlsx = pd.ExcelFile('final_df.xlsx')
final_df = pd.read_excel(xlsx)
final_df
# Out:
#            YearCountry        Country  Year  Gold  Silver  Bronze  Total  \
# 0          2000Armenia        Armenia  2000     0       0       1      1
# 1         2000Barbados       Barbados  2000     0       0       1      1
# 2         2000Cameroon       Cameroon  2000     1       0       0      1
# 3            2000Chile          Chile  2000     0       0       1      1
# 4         2000Colombia       Colombia  2000     1       0       0      1
# ..                 ...            ...   ...   ...     ...     ...    ...
# 501  2004United States  United States  2004    36      39      26    101
# 502        2012Vietnam        Vietnam  2012     0       0       1      1
# 503  2008United States  United States  2008    36      39      37    112
# 504  2020United States  United States  2020    39      41      33    113
# 505  2016United States  United States  2016    46      37      38    121
#
#      Athletes  Population       GDP   Latitude   Longitude  Altitude(meters)  \
# ...

# %%
inputs = ["Athletes", "GDP", 'Altitude(meters)', 'Host']
X = final_df[inputs]
y = final_df[["Total"]]
print(X.shape, y.shape)
# Out:
# (506, 4) (506, 1)

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X, y)
### END SOLUTION
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=42)

# %%
from sklearn.neural_network import MLPRegressor


regr = MLPRegressor((20, 20, 20, 20), max_iter = 500).fit(X_train, np.array(y_train['Total']))

# %%
regr.score(X_test, y_test)
# Out:
# 0.45333666755678637

# %%
# Read the csv file into a pandas DataFrame

xlsx = pd.ExcelFile('Predictor_DataFile.xlsx')
prediction_df = pd.read_excel(xlsx)

# %%
guessColName = 'guess_total'
prediction_df[guessColName]=regr.predict(prediction_df[inputs])

#reorder columns
d = {col : prediction_df[col] for col in prediction_df.columns if col != 'Total' and col != 'GuessedMedals'}
lastCols = ['Total', guessColName]
for col in lastCols:
    d[col] = prediction_df[col]
prediction_final = pd.DataFrame(d).tail(10)

# %%
prediction_final.to_excel ('prediction.xlsx', index = False, header=True)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
#model.fit(X_train_scaled, y_train_scaled)
model.fit(X_train_scaled, y_train)
### END SOLUTION
# Out:
# LinearRegression()

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
# Hint: You can predict values of X training and testing data using the model.predict() method on a fitted model

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
#model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), y_train_scaled - model.predict(X_train_scaled), c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), y_test - model.predict(X_test_scaled), c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
model.predict(X_test_scaled)
# Out:
# array([[ 7.57002063],
#        [ 6.7087939 ],
#        [35.22439492],
#        [ 4.48280284],
#        [ 7.88968063],
#        [10.0353962 ],
#        [ 3.34428201],
#        [ 7.86366296],
#        [32.06325474],
#        [19.73547945],
#        [ 9.85013551],
#        [ 4.43599018],
#        [22.01299244],
#        [ 9.57907951],
#        [11.87496907],
#        [41.6997137 ],
#        [ 6.7030687 ],
#        [ 9.34841342],
#        [15.95314703],
#        [ 6.820556  ],
#        [ 5.69477628],
#        [ 7.51411666],
#        [ 5.0889755 ],
#        [72.48425419],
#        [ 7.33618627],
#        [36.25356401],
#        [ 6.67919136],
#        [28.60711509],
#        [ 4.89955321],
#        [10.23155215],
#        [11.14050466],
#        [13.70149099],
#        [10.63472567],
#        [ 6.03356754],
#        [ 5.88580135],
#        [ 7.04485354],
#        [ 4.49670197],
#        [ 9.41865583],
#        [ 5.29382718],
#        [ 4.44638489],
#        [86.97051522],
# ...

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 393.8571945002013, R2: -161.40358529134434

# %%
model.predict(prediction_df[inputs])
# Out:
# array([[-9.34272061e+02],
#        [ 2.00402705e+01],
#        [-1.12760075e+02],
#        [ 5.33915176e+02],
#        [ 1.16053921e+02],
#        [ 4.36525117e+03],
#        [ 1.33493705e+03],
#        [ 1.33366547e+03],
#        [ 1.08761602e+04],
#        [-2.42083553e+01],
#        [-9.82956525e+02],
#        [ 5.58380117e+03],
#        [ 3.78428248e+03],
#        [ 4.17041974e+02],
#        [ 2.17598019e+03],
#        [ 2.17278075e+02],
#        [ 1.62547816e+02],
#        [-7.11686551e+01],
#        [ 7.30454947e+02],
#        [-3.06887879e+02],
#        [ 9.75135135e+02],
#        [ 2.21640348e+03],
#        [-1.64678507e+02],
#        [ 2.47780116e+03],
#        [ 3.21643489e+03],
#        [ 2.40353832e+02],
#        [ 1.47194037e+03],
#        [-7.52674702e+02],
#        [ 2.69749199e+02],
#        [ 1.46120764e+04],
#        [ 5.54494200e+02],
#        [-1.66320730e+02],
#        [ 1.95428880e+03],
#        [ 1.86991341e+03],
#        [-7.15282939e+01],
# ...
